# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
#data preprocessing
#training image processing

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)
training_set=train_datagen.flow_from_directory(
    'training_set',target_size=(64,64),batch_size=32,class_mode='categorical')
# Out:
# Found 4317 images belonging to 5 classes.

# %%
#test image processing

# %%
test_datagen=ImageDataGenerator(rescale=1./255)
test_set=test_datagen.flow_from_directory('test_set',target_size=(64,64),batch_size=32,class_mode='categorical')
# Out:
# Found 1004 images belonging to 5 classes.

# %%
#bulding model

# %%
cnn=tf.keras.models.Sequential()

# %%
#bulding convolution layer

# %%
cnn.add(tf.keras.layers.Conv2D(filters=64,kernel_size=3,activation='relu',input_shape=[64,64,3]))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %%
cnn.add(tf.keras.layers.Conv2D(filters=64,kernel_size=3,activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %%
cnn.add(tf.keras.layers.Dropout(0.5))

# %%
cnn.add(tf.keras.layers.Flatten())

# %%
cnn.add(tf.keras.layers.Dense(units=128,activation='relu'))

# %%
cnn.add(tf.keras.layers.Dense(units=5,activation='softmax'))

# %%
cnn.compile(optimizer='rmsprop',loss='categorical_crossentropy', metrics=['accuracy'])

# %%
cnn.fit(x=training_set, validation_data=test_set, epochs=30)
# Out:
# Epoch 1/30
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 23s 160ms/step - accuracy: 0.3234 - loss: 1.4858 - val_accuracy: 0.4681 - val_loss: 1.2467
# Epoch 2/30
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 156ms/step - accuracy: 0.5485 - loss: 1.1371 - val_accuracy: 0.5886 - val_loss: 0.9965
# Epoch 3/30
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 159ms/step - accuracy: 0.5995 - loss: 1.0181 - val_accuracy: 0.6614 - val_loss: 0.8800
# Epoch 4/30
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 158ms/step - accuracy: 0.6319 - loss: 0.9426 - val_accuracy: 0.6803 - val_loss: 0.8480
# Epoch 5/30
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 22s 161ms/step - accuracy: 0.6657 - loss: 0.8782 - val_accuracy: 0.6753 - val_loss: 0.8683
# Epoch 6/30
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 41s 158ms/step - accuracy: 0.6781 - loss: 0.8347 - val_accuracy: 0.6962 - val_loss: 0.7967
# Epoch 7/30
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 158ms/step - accuracy: 0.6918 - loss: 0.8246 - val_accuracy: 0.6892 - val_loss: 0.8201
# Epoch 8/30
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 41s 158ms/step - accuracy: 0.7056 - loss: 0.7913 - val_accuracy: 0.7271 - val_loss: 0.7346
# Epoch 9/30
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 159ms/step - accuracy: 0.7031 - loss: 0.7799 - val_accuracy: 0.7102 - val_loss: 0.7491
# Epoch 10/30
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 41s 158ms/step - accuracy: 0.7157 - loss: 0.7452 - val_accuracy: 0.7809 - val_loss: 0.6254
# Epoch 11/30
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 157ms/step - accuracy: 0.7303 - loss: 0.7034 - val_accuracy: 0.7709 - val_loss: 0.6255
# Epoch 12/30
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 158ms/step - accuracy: 0.7458 - loss: 0.6719 - val_accuracy: 0.8088 - val_loss: 0.5535
# Epoch 13/30
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 158ms/step - accuracy: 0.7560 - loss: 0.6546 - val_accuracy: 0.7689 - val_loss: 0.5907
# Epoch 14/30
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 159ms/step - accuracy: 0.7461 - loss: 0.6618 - val_accuracy: 0.8167 - val_loss: 0.5055
# Epoch 15/30
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 158ms/step - accuracy: 0.7540 - loss: 0.6555 - val_accuracy: 0.8108 - val_loss: 0.5211
# Epoch 16/30
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 41s 158ms/step - accuracy: 0.7689 - loss: 0.6172 - val_accuracy: 0.7390 - val_loss: 0.7033
# Epoch 17/30
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 22s 160ms/step - accuracy: 0.7632 - loss: 0.6332 - val_accuracy: 0.7839 - val_loss: 0.5968
# Epoch 18/30
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 158ms/step - accuracy: 0.7791 - loss: 0.6031 - val_accuracy: 0.8167 - val_loss: 0.4919
# Epoch 19/30
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 22s 160ms/step - accuracy: 0.7664 - loss: 0.6082 - val_accuracy: 0.7799 - val_loss: 0.5872
# Epoch 20/30
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 22s 159ms/step - accuracy: 0.7925 - loss: 0.5533 - val_accuracy: 0.8486 - val_loss: 0.4222
# Epoch 21/30
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 158ms/step - accuracy: 0.8062 - loss: 0.5464 - val_accuracy: 0.8496 - val_loss: 0.4213
# Epoch 22/30
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 158ms/step - accuracy: 0.8163 - loss: 0.4969 - val_accuracy: 0.8307 - val_loss: 0.4832
# Epoch 23/30
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 159ms/step - accuracy: 0.7990 - loss: 0.5455 - val_accuracy: 0.8486 - val_loss: 0.4163
# Epoch 24/30
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 22s 159ms/step - accuracy: 0.7970 - loss: 0.5448 - val_accuracy: 0.8655 - val_loss: 0.3795
# Epoch 25/30
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 159ms/step - accuracy: 0.8009 - loss: 0.5238 - val_accuracy: 0.8108 - val_loss: 0.5122
# Epoch 26/30
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 41s 162ms/step - accuracy: 0.8084 - loss: 0.5001 - val_accuracy: 0.8496 - val_loss: 0.4219
# Epoch 27/30
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 159ms/step - accuracy: 0.8218 - loss: 0.4883 - val_accuracy: 0.8606 - val_loss: 0.3537
# Epoch 28/30
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 158ms/step - accuracy: 0.8244 - loss: 0.4657 - val_accuracy: 0.8775 - val_loss: 0.3720
# Epoch 29/30
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 156ms/step - accuracy: 0.8156 - loss: 0.4974 - val_accuracy: 0.8875 - val_loss: 0.2942
# Epoch 30/30
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 155ms/step - accuracy: 0.8281 - loss: 0.4607 - val_accuracy: 0.9114 - val_loss: 0.2825

# %%
#preprocess new image

# %%
from keras.preprocessing import image
test_image = image.load_img('Prediction/tulip.jpg',target_size=(64,64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image,axis=0)
result = cnn.predict(test_image)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step

# %%
training_set.class_indices
# Out:
# {'daisy': 0, 'dandelion': 1, 'rose': 2, 'sunflower': 3, 'tulip': 4}

# %%
print(result)
# Out:
# [[0. 0. 0. 0. 1.]]

# %%
if result[0][0]==1:
    print('Daisy')
elif result[0][1]==1:
    print('Dandelion')
elif result[0][2]==1:
    print('Rose')
elif result[0][3]==1:
    print('Sunflower')
elif result[0][4]==1:
    print('Tulip')
# Out:
# Tulip
